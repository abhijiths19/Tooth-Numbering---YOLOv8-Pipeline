# %%
# !pip -q install ultralytics opencv-python pyyaml tqdm scikit-learn pandas numpy matplotlib
# !apt -q update && apt -q install -y p7zip-full > /dev/null
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 39 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import os
import sys
import io
import json
import csv
import shutil
import zipfile
import subprocess
from pathlib import Path
from typing import List, Tuple, Optional, Dict
import random
import yaml
import math
import numpy as np
import pandas as pd
import cv2
from tqdm import tqdm
from ultralytics import YOLO

# %%
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# %%
ZIP_PATH = Path("/content/ToothNumber_TaskDataset.zip")   # Input archive path
EXTRACT_ROOT = Path("/content/dataset_raw")
OUT_ROOT = Path("/content/dataset_prepared")              # Final YOLO-format dataset
RUNS_ROOT = Path("/content/runs")                         # Root for all outputs
SUBMISSION_DIR = RUNS_ROOT / "submission_artifacts"       # Consolidated deliverables
PRED_VIS_DIR = RUNS_ROOT / "predict_vis"                  # Raw prediction visuals
POSTPROC_VIS_DIR = RUNS_ROOT / "postproc_vis"             # Post-processed prediction visuals
SEED = 42
IMG_EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")
RECOMMENDED_IMG_SIZE = 640
EPOCHS = 5
BATCH = 16
CONF_THRESH = 0.25
IOU_THRESH = 0.7
NUM_INLINE_PREVIEWS = 6  # number of prediction images to display inline

# FDI Class list in the exact required order
FDI_CLASS_NAMES = [
    "Canine (13)","Canine (23)","Canine (33)","Canine (43)",
    "Central Incisor (21)","Central Incisor (41)","Central Incisor (31)","Central Incisor (11)",
    "First Molar (16)","First Molar (26)","First Molar (36)","First Molar (46)",
    "First Premolar (14)","First Premolar (34)","First Premolar (44)","First Premolar (24)",
    "Lateral Incisor (22)","Lateral Incisor (32)","Lateral Incisor (42)","Lateral Incisor (12)",
    "Second Molar (17)","Second Molar (27)","Second Molar (37)","Second Molar (47)",
    "Second Premolar (15)","Second Premolar (25)","Second Premolar (35)","Second Premolar (45)",
    "Third Molar (18)","Third Molar (28)","Third Molar (38)","Third Molar (48)"
]

# %%
def set_all_seeds(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    try:
        import torch
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    except Exception:
        pass

def file_info(p: Path):
    try:
        sz = p.stat().st_size
    except Exception:
        sz = None
    return {"exists": p.exists(), "size": sz, "suffix": p.suffix.lower()}

def extract_archive(src: Path, dest: Path) -> bool:
    if dest.exists():
        shutil.rmtree(dest)
    dest.mkdir(parents=True, exist_ok=True)

    extracted_ok = False
    err_msgs = []

    if src.is_dir():
        shutil.copytree(src, dest, dirs_exist_ok=True)
        extracted_ok = True
        return extracted_ok

    if src.is_file():
        try:
            if zipfile.is_zipfile(src):
                with zipfile.ZipFile(src, 'r') as zf:
                    zf.extractall(dest)
                extracted_ok = True
            else:
                err_msgs.append("Python zipfile: not recognized as ZIP.")
        except Exception as e:
            err_msgs.append(f"Python zipfile error: {e}")

    if not extracted_ok and src.is_file():
        try:
            code = subprocess.call(["unzip", "-q", "-o", str(src), "-d", str(dest)])
            if code == 0:
                extracted_ok = True
            else:
                err_msgs.append(f"unzip exit code {code}")
        except Exception as e:
            err_msgs.append(f"unzip error: {e}")

    if not extracted_ok and src.is_file():
        try:
            code = subprocess.call(["7z", "x", "-y", str(src), f"-o{dest}"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
            if code == 0:
                extracted_ok = True
            else:
                err_msgs.append(f"7z exit code {code}")
        except Exception as e:
            err_msgs.append(f"7z error: {e}")

    if not extracted_ok:
        print("Could not extract the file. Debug:", "; ".join(err_msgs))
    return extracted_ok

def find_best_images_dir(root: Path) -> Path:
    candidates = []
    for p in root.rglob("images"):
        cnt = sum(1 for f in p.glob("*") if f.suffix.lower() in IMG_EXTS)
        if cnt > 0:
            candidates.append((cnt, p))
    if root.name.lower() == "images":
        cnt = sum(1 for f in root.glob("*") if f.suffix.lower() in IMG_EXTS)
        if cnt > 0:
            candidates.append((cnt, root))
    if not candidates:
        raise FileNotFoundError("Couldn't find an 'images' folder that contains any images.")
    # sort by count descending, pick best
    candidates.sort(reverse=True, key=lambda x: x[0])
    return candidates[0][1]

def detect_labels_dir(images_dir: Path) -> Optional[Path]:
    cand = images_dir.parent / "labels"
    if cand.exists():
        return cand
    return None

def label_for_image(img_path: Path, labels_dir: Optional[Path]) -> Optional[Path]:
    same = img_path.with_suffix(".txt")
    if same.exists():
        return same
    if labels_dir is not None:
        cand = labels_dir / f"{img_path.stem}.txt"
        if cand.exists():
            return cand
    return None

def ensure_clean_dir(p: Path):
    if p.exists():
        shutil.rmtree(p)
    p.mkdir(parents=True, exist_ok=True)

def write_yaml(pth: Path, data: dict):
    with open(pth, "w", encoding="utf-8") as f:
        yaml.safe_dump(data, f, sort_keys=False, allow_unicode=True)

def safe_copy(src: Path, dst: Path):
    dst.parent.mkdir(parents=True, exist_ok=True
    )
    shutil.copy2(src, dst)

def yolo_save_dir_to_best(weights_dir: Path) -> Path:
    best = weights_dir / "weights" / "best.pt"
    if not best.exists():
        raise FileNotFoundError(f"best.pt not found under {weights_dir}")
    return best

def write_metrics_csv_json(metrics_dict: dict, out_csv: Path, out_json: Path):
    keys_of_interest = ["precision", "recall", "map50", "map"]
    row = {k: metrics_dict.get(k, None) for k in keys_of_interest}
    out_csv.parent.mkdir(parents=True, exist_ok=True)
    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=keys_of_interest)
        w.writeheader()
        w.writerow(row)
    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(metrics_dict, f, indent=2)

def list_and_copy_if_exists(src_dir: Path, filenames: List[str], dest_dir: Path):
    dest_dir.mkdir(parents=True, exist_ok=True)
    found = []
    for name in filenames:
        p = src_dir / name
        if p.exists():
            safe_copy(p, dest_dir / name)
            found.append(p)
    return found

# %%
# Extract dataset

print("Input:", ZIP_PATH, file_info(ZIP_PATH))
ok = extract_archive(ZIP_PATH, EXTRACT_ROOT)
if not ok:
    raise SystemExit("Extraction failed. Please provide a valid dataset archive or directory.")

print("Extracted to:", EXTRACT_ROOT)
# !ls -R /content/dataset_raw | head -100

# Pair images and labels, split 80/10/10, build data.yaml

set_all_seeds(SEED)

images_dir = find_best_images_dir(EXTRACT_ROOT)
labels_dir = detect_labels_dir(images_dir)
print("Using images dir:", images_dir)
print("Labels dir:", labels_dir if labels_dir else "Expecting .txt annotations next to images.")

ensure_clean_dir(OUT_ROOT)
(OUT_ROOT/"images").mkdir(parents=True, exist_ok=True)
(OUT_ROOT/"labels").mkdir(parents=True, exist_ok=True)

all_imgs = [p for p in images_dir.glob("*") if p.suffix.lower() in IMG_EXTS]
pairs, missing = [], 0
for img in all_imgs:
    lbl = label_for_image(img, labels_dir)
    if lbl:
        pairs.append((img, lbl))
    else:
        missing += 1
print(f"Found {len(pairs)} image/label pairs. Missing labels for {missing} images.")

random.shuffle(pairs)
n = len(pairs)
n_train, n_val = int(0.8 * n), int(0.1 * n)
splits = {
    "train": pairs[:n_train],
    "val": pairs[n_train:n_train + n_val],
    "test": pairs[n_train + n_val:]
}

for split, items in splits.items():
    (OUT_ROOT/"images"/split).mkdir(parents=True, exist_ok=True)
    (OUT_ROOT/"labels"/split).mkdir(parents=True, exist_ok=True)
    for im, lbl in tqdm(items, desc=f"Copying {split}", unit="file"):
        safe_copy(im, OUT_ROOT/"images"/split/im.name)
        safe_copy(lbl, OUT_ROOT/"labels"/split/f"{im.stem}.txt")

data_yaml = {
    "train": str(OUT_ROOT/"images"/"train"),
    "val": str(OUT_ROOT/"images"/"val"),
    "test": str(OUT_ROOT/"images"/"test"),
    "names": {i: n for i, n in enumerate(FDI_CLASS_NAMES)}
}
write_yaml(OUT_ROOT/"data.yaml", data_yaml)
print("Prepared dataset at:", OUT_ROOT)
print("data.yaml:", OUT_ROOT/"data.yaml")
# Out:
# Input: /content/ToothNumber_TaskDataset.zip {'exists': True, 'size': 42629954, 'suffix': '.zip'}
# Extracted to: /content/dataset_raw
# /content/dataset_raw:
# images
# labels
#
# /content/dataset_raw/images:
# 00147087-20240918-120248027.jpg
# 0337fb14-20240822-124747143.jpg
# 05473f26-20240924-154033777.jpg
# 05ff01fa-20250108-115407401.jpg
# 061339f1-20240911-110938655.jpg
# 069750f6-20240914-102814322.jpg
# 084c3562-20240827-154718191.jpg
# 0ba65172-20240821-105924223.jpg
# 0c4cebbe-20240813-144203674.jpg
# 0fcae64f-20241217-121556078.jpg
# 0fd502a1-20250123-111857443.jpg
# 103dd85b-20240831-101746682.jpg
# 124e696d-20240914-105651782.jpg
# 1459fc45-20240831-113821806.jpg
# 16a28cd9-20240723-113852192.jpg
# 18fd6ab8-20250415-143542497.jpg
# 1b000dc7-20240813-115604759.jpg
# 1c50bda9-20241231-145320490.jpg
# 1fc5e51d-20241219-142523942.jpg
# 22464331-20240919-102844605.jpg
# 23f1d012-20240628-115132889.jpg
# 26f91eeb-20240903-150428112.jpg
# 271041ce-20250421-112436631.jpg
# 2725830c-20240829-130426513.jpg
# 281350f8-20240813-145334040.jpg
# 28c54465-20240727-114541091.jpg
# 2b1da7b0-20240813-114403429.jpg
# 2d580460-20240730-115355708.jpg
# 2d87cff9-20240801-161145471.jpg
# 2da3d47d-20240711-112718798.jpg
# 2fdef93e-20240909-110147718.jpg
# 2fe06363-20240824-105311188.jpg
# 30b9d3cc-20240910-115056042.jpg
# 3213a9e9-20250416-114005066.jpg
# 323ff022-20241216-114250488.jpg
# 32bf2ab8-20250429-143954461.jpg
# 3357f3d4-20240824-123243101.jpg
# 3a483ad5-20240827-120738078.jpg
# 3eb9bb4a-20240713-104413422.jpg
# 3ffe5987-20240830-141140390.jpg
# 420d50e5-20240824-122516254.jpg
# 42fab84f-20240829-124908672.jpg
# 433cab04-20241004-124015120.jpg
# 44745553-20240807-104950484.jpg
# 448a529c-20240810-121007744.jpg
# 46f25eb3-20240716-144513555.jpg
# 49cea1f0-20240709-100623478.jpg
# 4a54fcae-20240808-115419598.jpg
# 4b0b800d-20240619-131850233.jpg
# 4b9ffa7d-20250502-151642682.jpg
# 4d49f965-20240627-131900667.jpg
# 52a27ed0-20240808-113506387.jpg
# 52ca82f2-20241206-111446878.jpg
# 54aabd9e-20240530-153639805.jpg
# 54fb1a18-20250425-161141385.jpg
# 57f405c1-20240726-112759687.jpg
# 5ac74e43-20240917-113511459.jpg
# 5b9cbf85-20240620-151246826.jpg
# 5c05f3c4-20240822-122358263.jpg
# 5daeeade-20250122-145335608.jpg
# 61e47c05-20240709-160829783.jpg
# 6314a068-20240927-143552569.jpg
# 660565ec-20240713-125046882.jpg
# 66bfe50b-20240425-144130348.jpg
# 695829ba-20240803-122506348.jpg
# 6d2d78f3-20250507-105238161.jpg
# 6e25988d-20240812-124057491.jpg
# 6f2e436d-20240911-130622990.jpg
# 6fb0e6ae-20240914-130826679.jpg
# 6fbdc5b9-20240712-100756315.jpg
# 7015ad0f-20250210-143051360.jpg
# 73b95a6f-20240909-115239356.jpg
# 73ffa9a1-20240615-122751488.jpg
# 748a54d0-20240820-104104646.jpg
# 74d3673e-20250502-143252934.jpg
# 75ca9ab4-20250110-121536031.jpg
# 77cbfd44-20250507-104302199.jpg
# 77cf60c6-20250502-152837733.jpg
# 7b27f339-20240914-101612388.jpg
# 7e07ad10-20240819-103441968.jpg
# 7edbcabb-20250429-144338802.jpg
# 810dddc7-20250124-121432613.jpg
# 844106b0-20250108-120043107.jpg
# 868e37bc-20240801-122009445.jpg
# 88f159b5-20240918-102728832.jpg
# 8a1eaeb2-20250505-144038154.jpg
# 8c9093d1-20240831-113602146.jpg
# 9056d1d7-20250120-112359817.jpg
# 91238e26-20240808-112853454.jpg
# 9397380b-20241001-112203944.jpg
# 9584287f-20240621-113024889.jpg
# 970a5f03-20250206-125245740.jpg
# 99e7de0c-20240917-130758225.jpg
# 9b7a35cd-20240921-105800596.jpg
# 9ca65473-20240907-123247574.jpg
# Using images dir: /content/dataset_raw/images
# Labels dir: /content/dataset_raw/labels
# Found 497 image/label pairs. Missing labels for 0 images.
# Copying train: 100%|██████████| 397/397 [00:00<00:00, 2497.64file/s]
# Copying val: 100%|██████████| 49/49 [00:00<00:00, 2444.41file/s]
# Copying test: 100%|██████████| 51/51 [00:00<00:00, 2358.71file/s]
# Prepared dataset at: /content/dataset_prepared
# data.yaml: /content/dataset_prepared/data.yaml

# %%
# Train YOLOv8

ensure_clean_dir(RUNS_ROOT)
model = YOLO("yolov8s.pt")
train_results = model.train(
    data=str(OUT_ROOT/"data.yaml"),
    imgsz=RECOMMENDED_IMG_SIZE,
    epochs=EPOCHS,
    batch=BATCH,
    project=str(RUNS_ROOT),
    name="train",
    verbose=True
)
train_save_dir = Path(train_results.save_dir)
best_pt = yolo_save_dir_to_best(train_save_dir)
print("Training run dir:", train_save_dir)
print("Best weights:", best_pt)
# Out:
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset_prepared/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=32
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2128432  ultralytics.nn.modules.head.Detect           [32, [128, 256, 512]]
# Model summary: 129 layers, 11,147,984 parameters, 11,147,968 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1327.6±573.3 MB/s, size: 91.0 KB)
# train: Scanning /content/dataset_prepared/labels/train... 397 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 397/397 1687.5it/s 0.2s
# train: New cache created: /content/dataset_prepared/labels/train.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 63, len(boxes) = 10974. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 796.8±299.9 MB/s, size: 57.6 KB)
# val: Scanning /content/dataset_prepared/labels/val... 49 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 49/49 1458.8it/s 0.0s
# val: New cache created: /content/dataset_prepared/labels/val.cache
# Plotting labels to /content/runs/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000278, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /content/runs/train
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      2.047      4.814      1.672        464        640: 100% ━━━━━━━━━━━━ 25/25 0.03it/s 15:58
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50% ━━━━━━────── 1/2 0.01it/s 30.7sWARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.04it/s 46.4s
#                    all         49       1461     0.0643     0.0569     0.0393     0.0257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      1.471       2.96      1.268        512        640: 100% ━━━━━━━━━━━━ 25/25 0.03it/s 15:55
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50% ━━━━━━────── 1/2 0.01it/s 28.8sWARNING ⚠️ NMS time limit 2.850s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.04it/s 45.3s
#                    all         49       1461      0.145      0.312      0.129     0.0833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5         0G      1.381      2.221      1.225        393        640: 100% ━━━━━━━━━━━━ 25/25 0.03it/s 15:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.05it/s 40.9s
#                    all         49       1461        0.2      0.682      0.278      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5         0G      1.311      1.988      1.171        596        640: 100% ━━━━━━━━━━━━ 25/25 0.03it/s 15:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.05it/s 40.6s
#                    all         49       1461      0.296      0.694      0.373      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5         0G      1.299      1.876      1.181        564        640: 100% ━━━━━━━━━━━━ 25/25 0.03it/s 15:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.05it/s 39.6s
#                    all         49       1461      0.319      0.738        0.4      0.264
#
# 5 epochs completed in 1.372 hours.
# Optimizer stripped from /content/runs/train/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/train/weights/best.pt, 22.5MB
#
# Validating /content/runs/train/weights/best.pt...
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 11,137,968 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.05it/s 37.7s
#                    all         49       1461       0.32       0.74      0.401      0.264
#            Canine (13)         49         49      0.309      0.755      0.332      0.223
#            Canine (23)         48         48       0.25      0.236      0.279      0.173
#            Canine (33)         49         49      0.327      0.673      0.448      0.272
#            Canine (43)         48         48      0.272      0.729      0.307       0.21
#   Central Incisor (21)         48         48      0.297      0.917       0.46      0.295
#   Central Incisor (41)         49         49      0.239      0.878      0.432      0.197
#   Central Incisor (31)         49         49      0.285      0.939      0.388      0.205
#   Central Incisor (11)         49         49      0.409      0.849       0.55       0.36
#       First Molar (16)         45         45      0.341      0.911      0.345       0.23
#       First Molar (26)         44         44      0.305      0.886      0.451      0.343
#       First Molar (36)         40         40      0.485       0.95      0.554      0.385
#       First Molar (46)         40         40       0.44      0.875      0.579      0.467
#    First Premolar (14)         47         47      0.317      0.255      0.274      0.161
#    First Premolar (34)         48         48      0.296      0.833      0.397      0.264
#    First Premolar (44)         49         49      0.228      0.653      0.236      0.156
#    First Premolar (24)         46         46      0.242      0.391      0.241      0.123
#   Lateral Incisor (22)         48         48      0.313      0.708      0.366      0.207
#   Lateral Incisor (32)         48         48       0.26      0.771      0.297      0.171
#   Lateral Incisor (42)         48         48      0.186      0.792      0.293      0.156
#   Lateral Incisor (12)         48         48      0.154     0.0625      0.203      0.129
#      Second Molar (17)         47         47      0.246      0.957      0.403      0.332
#      Second Molar (27)         46         47      0.305      0.851      0.464      0.331
#      Second Molar (37)         43         43      0.312      0.927      0.393      0.307
#      Second Molar (47)         42         42      0.296      0.976      0.548      0.452
#   Second Premolar (15)         44         44      0.369      0.455      0.332       0.21
#   Second Premolar (25)         43         43       0.31      0.501      0.283      0.172
#   Second Premolar (35)         49         49      0.386      0.837      0.531      0.339
#   Second Premolar (45)         47         47      0.378      0.809      0.526      0.378
#       Third Molar (18)         41         41      0.464      0.782      0.516       0.31
#       Third Molar (28)         41         41      0.365       0.61      0.388      0.196
#       Third Molar (38)         38         38      0.421      0.947      0.468      0.351
#       Third Molar (48)         39         39      0.419      0.949      0.536      0.348
# Speed: 3.1ms preprocess, 709.8ms inference, 0.0ms loss, 45.2ms postprocess per image
# Results saved to /content/runs/train
# Training run dir: /content/runs/train
# Best weights: /content/runs/train/weights/best.pt

# %%
# Evaluate on val and test, save metrics and confusion matrices

ensure_clean_dir(SUBMISSION_DIR)

# Validation
val_metrics = YOLO(str(best_pt)).val(
    data=str(OUT_ROOT/"data.yaml"),
    split="val",
    plots=True,
    save_json=True,
    project=str(RUNS_ROOT),
    name="val_eval"
)
val_dir = Path(val_metrics.save_dir)
print("VAL:", val_metrics.results_dict)

write_metrics_csv_json(
    val_metrics.results_dict,
    SUBMISSION_DIR / "metrics_val.csv",
    SUBMISSION_DIR / "metrics_val.json"
)

val_artifacts = [
    "confusion_matrix.png",
    "confusion_matrix_normalized.png",
    "P_curve.png",
    "R_curve.png",
    "PR_curve.png",
    "F1_curve.png",
    "results.png",
    "labels_correlogram.jpg",
    "labels.jpg"
]
list_and_copy_if_exists(val_dir, val_artifacts, SUBMISSION_DIR / "val_plots")

# Test
test_metrics = YOLO(str(best_pt)).val(
    data=str(OUT_ROOT/"data.yaml"),
    split="test",
    plots=True,
    save_json=True,
    project=str(RUNS_ROOT),
    name="test_eval"
)
test_dir = Path(test_metrics.save_dir)
print("TEST:", test_metrics.results_dict)

write_metrics_csv_json(
    test_metrics.results_dict,
    SUBMISSION_DIR / "metrics_test.csv",
    SUBMISSION_DIR / "metrics_test.json"
)
list_and_copy_if_exists(test_dir, val_artifacts, SUBMISSION_DIR / "test_plots")

print("Validation plots dir:", val_dir)
print("Test plots dir:", test_dir)
print("Submission artifacts dir:", SUBMISSION_DIR)
# Out:
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 11,137,968 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1383.4±295.9 MB/s, size: 89.0 KB)
# val: Scanning /content/dataset_prepared/labels/val.cache... 49 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 49/49 57344.0it/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.10it/s 40.4s
#                    all         49       1461       0.32       0.74      0.401      0.264
#            Canine (13)         49         49      0.309      0.755      0.332      0.223
#            Canine (23)         48         48       0.25      0.236      0.279      0.173
#            Canine (33)         49         49      0.327      0.673      0.448      0.272
#            Canine (43)         48         48      0.272      0.729      0.307       0.21
#   Central Incisor (21)         48         48      0.297      0.917       0.46      0.295
#   Central Incisor (41)         49         49      0.239      0.878      0.432      0.197
#   Central Incisor (31)         49         49      0.285      0.939      0.388      0.205
#   Central Incisor (11)         49         49      0.409      0.849       0.55       0.36
#       First Molar (16)         45         45      0.341      0.911      0.345       0.23
#       First Molar (26)         44         44      0.305      0.886      0.451      0.343
#       First Molar (36)         40         40      0.485       0.95      0.554      0.385
#       First Molar (46)         40         40       0.44      0.875      0.579      0.467
#    First Premolar (14)         47         47      0.317      0.255      0.274      0.161
#    First Premolar (34)         48         48      0.296      0.833      0.397      0.264
#    First Premolar (44)         49         49      0.228      0.653      0.236      0.156
#    First Premolar (24)         46         46      0.242      0.391      0.241      0.123
#   Lateral Incisor (22)         48         48      0.313      0.708      0.366      0.207
#   Lateral Incisor (32)         48         48       0.26      0.771      0.297      0.171
#   Lateral Incisor (42)         48         48      0.186      0.792      0.293      0.156
#   Lateral Incisor (12)         48         48      0.154     0.0625      0.203      0.129
#      Second Molar (17)         47         47      0.246      0.957      0.403      0.332
#      Second Molar (27)         46         47      0.305      0.851      0.464      0.331
#      Second Molar (37)         43         43      0.312      0.927      0.393      0.307
#      Second Molar (47)         42         42      0.296      0.976      0.548      0.452
#   Second Premolar (15)         44         44      0.369      0.455      0.332       0.21
#   Second Premolar (25)         43         43       0.31      0.501      0.283      0.172
#   Second Premolar (35)         49         49      0.386      0.837      0.531      0.339
#   Second Premolar (45)         47         47      0.378      0.809      0.526      0.378
#       Third Molar (18)         41         41      0.464      0.782      0.516       0.31
#       Third Molar (28)         41         41      0.365       0.61      0.388      0.196
#       Third Molar (38)         38         38      0.421      0.947      0.468      0.351
#       Third Molar (48)         39         39      0.419      0.949      0.536      0.348
# Speed: 3.7ms preprocess, 729.7ms inference, 0.0ms loss, 63.8ms postprocess per image
# Saving /content/runs/val_eval/predictions.json...
# Results saved to /content/runs/val_eval
# VAL: {'metrics/precision(B)': 0.31953545503713543, 'metrics/recall(B)': 0.7395313390966923, 'metrics/mAP50(B)': 0.4005975582776565, 'metrics/mAP50-95(B)': 0.2641968788979751, 'fitness': 0.27783694683594323}
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 11,137,968 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 29.6±14.2 MB/s, size: 92.9 KB)
# val: Scanning /content/dataset_prepared/labels/test... 51 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51 447.5it/s 0.1s
# val: New cache created: /content/dataset_prepared/labels/test.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 34, len(boxes) = 1413. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.09it/s 43.0s
#                    all         51       1413       0.31      0.673      0.376      0.243
#            Canine (13)         43         43      0.236      0.605      0.324      0.188
#            Canine (23)         44         45      0.223      0.197       0.22      0.133
#            Canine (33)         49         49      0.348      0.633      0.393      0.263
#            Canine (43)         50         50      0.223       0.54      0.227      0.147
#   Central Incisor (21)         45         45      0.287      0.867      0.423      0.234
#   Central Incisor (41)         51         51      0.246      0.784      0.334      0.157
#   Central Incisor (31)         50         50      0.312       0.92       0.38      0.191
#   Central Incisor (11)         45         45      0.388        0.8      0.537      0.353
#       First Molar (16)         44         44      0.316      0.841      0.429      0.297
#       First Molar (26)         44         44      0.321      0.841      0.426      0.279
#       First Molar (36)         38         39      0.434      0.846      0.468      0.336
#       First Molar (46)         38         38      0.338      0.805      0.563       0.41
#    First Premolar (14)         42         42      0.284      0.246      0.253       0.13
#    First Premolar (34)         47         47      0.261      0.571      0.331      0.216
#    First Premolar (44)         47         47      0.252      0.638      0.252      0.167
#    First Premolar (24)         44         44      0.245      0.364      0.245      0.144
#   Lateral Incisor (22)         45         45      0.382        0.8      0.381      0.209
#   Lateral Incisor (32)         50         52      0.211      0.525      0.208      0.112
#   Lateral Incisor (42)         51         51      0.184      0.717      0.231      0.129
#   Lateral Incisor (12)         45         45      0.398      0.133      0.249      0.144
#      Second Molar (17)         45         45      0.261      0.956      0.436      0.334
#      Second Molar (27)         43         43      0.305      0.837      0.385      0.244
#      Second Molar (37)         40         40      0.278      0.925      0.348       0.26
#      Second Molar (47)         43         43      0.328      0.953      0.582      0.457
#   Second Premolar (15)         41         41      0.348       0.39      0.363      0.233
#   Second Premolar (25)         44         44      0.343      0.432      0.331      0.223
#   Second Premolar (35)         44         44      0.288      0.624      0.457      0.259
#   Second Premolar (45)         48         48      0.357      0.625      0.372      0.261
#       Third Molar (18)         37         37      0.424      0.649      0.454      0.308
#       Third Molar (28)         37         37      0.343      0.649      0.385      0.232
#       Third Molar (38)         40         40      0.412      0.858      0.443      0.311
#       Third Molar (48)         35         35      0.359      0.971      0.602      0.404
# Speed: 2.2ms preprocess, 780.6ms inference, 0.0ms loss, 45.2ms postprocess per image
# Saving /content/runs/test_eval/predictions.json...
# Results saved to /content/runs/test_eval
# TEST: {'metrics/precision(B)': 0.310465986915691, 'metrics/recall(B)': 0.6731881895864074, 'metrics/mAP50(B)': 0.3759455311403077, 'metrics/mAP50-95(B)': 0.24262645796157453, 'fitness': 0.2559583652794479}
# Validation plots dir: /content/runs/val_eval
# Test plots dir: /content/runs/test_eval
# Submission artifacts dir: /content/runs/submission_artifacts

# %%
# Sample predictions on test images (save and display inline)

ensure_clean_dir(PRED_VIS_DIR)
pred_results = YOLO(str(best_pt)).predict(
    source=str(OUT_ROOT/"images"/"test"),
    save=True,
    conf=CONF_THRESH,
    iou=IOU_THRESH,
    imgsz=RECOMMENDED_IMG_SIZE,
    project=str(PRED_VIS_DIR.parent),
    name=PRED_VIS_DIR.name
)
print("Predictions saved under:", PRED_VIS_DIR)
# Out:
# image 1/51 /content/dataset_prepared/images/test/069750f6-20240914-102814322.jpg: 640x640 1 Central Incisor (21), 2 Central Incisor (41)s, 2 First Molar (36)s, 2 Lateral Incisor (22)s, 3 Lateral Incisor (32)s, 3 Lateral Incisor (42)s, 1 Second Molar (17), 1 Second Molar (27), 1 Third Molar (28), 1 Third Molar (48), 572.2ms
# image 2/51 /content/dataset_prepared/images/test/084c3562-20240827-154718191.jpg: 640x640 3 Canine (13)s, 1 Canine (33), 3 Central Incisor (21)s, 4 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (36), 1 First Molar (46), 2 Lateral Incisor (22)s, 1 Second Molar (17), 1 Second Molar (27), 2 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (35), 2 Third Molar (48)s, 545.6ms
# image 3/51 /content/dataset_prepared/images/test/22464331-20240919-102844605.jpg: 640x640 1 Canine (33), 3 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 2 First Molar (26)s, 2 First Molar (36)s, 3 First Molar (46)s, 2 First Premolar (44)s, 1 First Premolar (24), 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (15), 3 Second Premolar (35)s, 1 Third Molar (18), 2 Third Molar (38)s, 2 Third Molar (48)s, 589.4ms
# image 4/51 /content/dataset_prepared/images/test/2725830c-20240829-130426513.jpg: 640x640 2 Central Incisor (21)s, 2 Central Incisor (41)s, 3 First Molar (26)s, 1 First Molar (36), 3 First Molar (46)s, 1 First Premolar (14), 1 First Premolar (44), 3 Lateral Incisor (22)s, 1 Lateral Incisor (32), 1 Lateral Incisor (42), 2 Second Molar (17)s, 4 Second Molar (37)s, 3 Second Molar (47)s, 2 Second Premolar (35)s, 1 Third Molar (28), 2 Third Molar (48)s, 559.8ms
# image 5/51 /content/dataset_prepared/images/test/2b1da7b0-20240813-114403429.jpg: 640x640 1 Canine (33), 2 Central Incisor (21)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (44), 1 First Premolar (24), 2 Lateral Incisor (22)s, 2 Lateral Incisor (32)s, 3 Lateral Incisor (42)s, 3 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 2 Second Molar (47)s, 2 Second Premolar (15)s, 1 Second Premolar (25), 2 Second Premolar (35)s, 1 Second Premolar (45), 2 Third Molar (38)s, 2 Third Molar (48)s, 543.8ms
# image 6/51 /content/dataset_prepared/images/test/2d87cff9-20240801-161145471.jpg: 640x640 1 Central Incisor (21), 2 Central Incisor (11)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (36), 2 Lateral Incisor (22)s, 3 Second Molar (17)s, 1 Second Molar (37), 3 Second Molar (47)s, 1 Third Molar (38), 2 Third Molar (48)s, 557.5ms
# image 7/51 /content/dataset_prepared/images/test/3ffe5987-20240830-141140390.jpg: 640x640 2 Central Incisor (21)s, 3 Central Incisor (41)s, 3 Central Incisor (31)s, 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 2 Second Molar (17)s, 2 Second Molar (27)s, 1 Third Molar (38), 2 Third Molar (48)s, 545.4ms
# image 8/51 /content/dataset_prepared/images/test/46f25eb3-20240716-144513555.jpg: 640x640 2 Canine (33)s, 1 Canine (43), 1 Central Incisor (41), 3 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (36), 1 First Molar (46), 2 Lateral Incisor (42)s, 5 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 2 Second Molar (47)s, 2 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 558.5ms
# image 9/51 /content/dataset_prepared/images/test/4a54fcae-20240808-115419598.jpg: 640x640 2 Central Incisor (21)s, 3 Central Incisor (41)s, 1 First Molar (26), 2 First Molar (36)s, 1 Lateral Incisor (22), 1 Second Molar (17), 1 Second Molar (27), 2 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (35), 2 Third Molar (28)s, 2 Third Molar (48)s, 542.9ms
# image 10/51 /content/dataset_prepared/images/test/57f405c1-20240726-112759687.jpg: 640x640 1 Canine (13), 2 Central Incisor (21)s, 1 Central Incisor (41), 2 Central Incisor (31)s, 1 First Molar (16), 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 3 First Premolar (44)s, 2 Lateral Incisor (22)s, 1 Lateral Incisor (32), 4 Second Molar (17)s, 2 Second Molar (27)s, 4 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (25), 3 Second Premolar (35)s, 1 Third Molar (28), 1 Third Molar (38), 2 Third Molar (48)s, 620.9ms
# image 11/51 /content/dataset_prepared/images/test/61e47c05-20240709-160829783.jpg: 640x640 1 Canine (33), 2 Central Incisor (21)s, 2 Central Incisor (41)s, 1 Central Incisor (31), 2 First Molar (16)s, 1 First Molar (36), 1 First Premolar (24), 5 Lateral Incisor (22)s, 1 Second Molar (17), 1 Second Molar (27), 3 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (35), 1 Third Molar (48), 852.4ms
# image 12/51 /content/dataset_prepared/images/test/a5c76dbc-20240729-122640382.jpg: 640x640 2 Canine (13)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (34), 3 Lateral Incisor (22)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 2 Second Premolar (35)s, 2 Second Premolar (45)s, 1 Third Molar (28), 854.2ms
# image 13/51 /content/dataset_prepared/images/test/b94abb31-20250429-142751426.jpg: 640x640 1 Canine (33), 2 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 3 First Molar (16)s, 3 First Molar (26)s, 2 First Molar (36)s, 2 First Molar (46)s, 2 First Premolar (34)s, 2 First Premolar (44)s, 1 First Premolar (24), 3 Lateral Incisor (22)s, 2 Second Molar (17)s, 1 Second Molar (27), 3 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (15), 3 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 683.7ms
# image 14/51 /content/dataset_prepared/images/test/bd3e04e6-20240808-115757352.jpg: 640x640 3 Canine (13)s, 1 Canine (33), 2 Central Incisor (21)s, 5 Central Incisor (41)s, 1 Central Incisor (31), 1 Central Incisor (11), 1 First Molar (16), 1 First Molar (26), 2 First Molar (36)s, 2 First Molar (46)s, 1 First Premolar (34), 1 First Premolar (44), 2 First Premolar (24)s, 2 Lateral Incisor (22)s, 2 Second Molar (17)s, 1 Second Molar (37), 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (25), 2 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (48)s, 558.4ms
# image 15/51 /content/dataset_prepared/images/test/cate1-00035_jpg.rf.e82433024ad10ea2a258614c2a8d3c5f.jpg: 640x640 2 Canine (13)s, 1 Canine (33), 3 Canine (43)s, 2 Central Incisor (21)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 3 First Molar (16)s, 3 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (34), 4 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 3 Second Molar (17)s, 1 Second Molar (37), 3 Second Molar (47)s, 1 Second Premolar (25), 1 Second Premolar (45), 3 Third Molar (18)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 539.2ms
# image 16/51 /content/dataset_prepared/images/test/cate1-00038_jpg.rf.3c63a693eae24c5155b6f1282928630d.jpg: 640x640 1 Canine (43), 3 Central Incisor (21)s, 4 Central Incisor (41)s, 4 Central Incisor (31)s, 2 Central Incisor (11)s, 4 First Molar (16)s, 3 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (24), 1 Lateral Incisor (22), 4 Lateral Incisor (42)s, 4 Second Molar (17)s, 4 Second Molar (37)s, 3 Second Molar (47)s, 1 Second Premolar (25), 2 Third Molar (48)s, 561.2ms
# image 17/51 /content/dataset_prepared/images/test/cate10-00056_jpg.rf.e283da4454bc0607fd574ffbdbb20db6.jpg: 640x640 2 Canine (33)s, 1 Central Incisor (41), 1 Central Incisor (31), 3 Lateral Incisor (42)s, 545.4ms
# image 18/51 /content/dataset_prepared/images/test/cate10-00096_jpg.rf.847ccd33e35016442a58b3832dfcc488.jpg: 640x640 3 Canine (33)s, 4 Canine (43)s, 3 Central Incisor (21)s, 2 Central Incisor (41)s, 3 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 2 First Molar (46)s, 2 First Premolar (44)s, 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 1 Second Molar (17), 2 Second Molar (27)s, 1 Second Molar (37), 2 Second Molar (47)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 1 Third Molar (48), 556.0ms
# image 19/51 /content/dataset_prepared/images/test/cate10-00099_jpg.rf.930b392526a8d7c5bd58de4ef8d8913b.jpg: 640x640 1 Canine (43), 539.7ms
# image 20/51 /content/dataset_prepared/images/test/cate2-00002_jpg.rf.88df00cce5a1d60ebf0e6b7fd48b8e71.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Canine (43)s, 3 Central Incisor (21)s, 1 Central Incisor (41), 3 Central Incisor (31)s, 2 Central Incisor (11)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (46), 1 First Premolar (34), 3 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 1 Lateral Incisor (42), 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (47), 1 Second Premolar (45), 1 Third Molar (28), 2 Third Molar (38)s, 3 Third Molar (48)s, 551.8ms
# image 21/51 /content/dataset_prepared/images/test/cate2-00010_jpg.rf.8deab81916101ce7c23a61d31df4459b.jpg: 640x640 1 Canine (43), 4 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 3 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (46), 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 4 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (38), 2 Third Molar (48)s, 559.6ms
# image 22/51 /content/dataset_prepared/images/test/cate2-00014_jpg.rf.d7f786ae7e337fd90b4661215a8692fb.jpg: 640x640 1 Canine (33), 3 Canine (43)s, 1 Central Incisor (21), 1 Central Incisor (41), 2 First Molar (16)s, 3 First Molar (26)s, 2 First Molar (46)s, 1 First Premolar (34), 2 First Premolar (44)s, 4 Second Molar (17)s, 1 Second Molar (27), 3 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (38), 1 Third Molar (48), 540.6ms
# image 23/51 /content/dataset_prepared/images/test/cate2-00020_jpg.rf.16b91f29e3feccbedf95e0ab37e4dd37.jpg: 640x640 1 Canine (13), 1 Canine (33), 3 Canine (43)s, 3 Central Incisor (21)s, 2 Central Incisor (31)s, 1 First Molar (16), 2 First Molar (26)s, 1 First Molar (46), 1 First Premolar (34), 1 First Premolar (44), 2 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (37)s, 3 Second Molar (47)s, 2 Second Premolar (25)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 556.4ms
# image 24/51 /content/dataset_prepared/images/test/cate2-00024_jpg.rf.fcdad1d1e96e782bead30ea33af7ed9f.jpg: 640x640 2 Canine (13)s, 1 Canine (23), 2 Canine (43)s, 2 Central Incisor (21)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (44), 1 First Premolar (24), 2 Lateral Incisor (42)s, 2 Second Molar (17)s, 2 Second Molar (27)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 2 Third Molar (18)s, 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 543.1ms
# image 25/51 /content/dataset_prepared/images/test/cate2-00109_jpg.rf.4f7ba9a179030058bf19f2f8cb3958b1.jpg: 640x640 1 Canine (33), 2 Canine (43)s, 3 Central Incisor (41)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 2 First Premolar (44)s, 3 Lateral Incisor (22)s, 1 Lateral Incisor (32), 1 Lateral Incisor (42), 2 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 3 Second Molar (47)s, 2 Second Premolar (25)s, 1 Second Premolar (35), 3 Second Premolar (45)s, 2 Third Molar (18)s, 1 Third Molar (28), 1 Third Molar (38), 2 Third Molar (48)s, 555.4ms
# image 26/51 /content/dataset_prepared/images/test/cate4-00094_jpg.rf.75f97439f6514548ed5deec49508d88c.jpg: 640x640 2 Canine (43)s, 2 Central Incisor (21)s, 4 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (34), 2 First Premolar (44)s, 1 Lateral Incisor (32), 2 Lateral Incisor (42)s, 4 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 2 Second Molar (47)s, 2 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (18)s, 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 547.8ms
# image 27/51 /content/dataset_prepared/images/test/cate4-00131_jpg.rf.dceada043e33cbad1bc1b57ed1243bfc.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Canine (43)s, 1 Central Incisor (21), 2 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (26), 2 First Molar (36)s, 2 First Molar (46)s, 2 First Premolar (34)s, 2 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 1 Lateral Incisor (42), 3 Second Molar (17)s, 1 Second Molar (37), 2 Second Molar (47)s, 1 Second Premolar (25), 3 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 562.1ms
# image 28/51 /content/dataset_prepared/images/test/cate5-00024_jpg.rf.56e9a8ce944902108d3fc06b7e082c18.jpg: 640x640 2 Canine (13)s, 1 Canine (43), 1 Central Incisor (21), 2 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 3 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 1 First Molar (46), 1 First Premolar (44), 1 Lateral Incisor (22), 3 Lateral Incisor (42)s, 2 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Premolar (45), 1 Third Molar (38), 1 Third Molar (48), 552.4ms
# image 29/51 /content/dataset_prepared/images/test/cate5-00078_jpg.rf.00ab602ee40aaa203757588ec19bd491.jpg: 640x640 1 Canine (33), 2 Central Incisor (41)s, 3 Central Incisor (31)s, 1 First Premolar (34), 1 First Premolar (44), 4 Lateral Incisor (32)s, 2 Lateral Incisor (42)s, 1 Second Molar (37), 2 Second Molar (47)s, 1 Third Molar (48), 559.6ms
# image 30/51 /content/dataset_prepared/images/test/cate5-00102_jpg.rf.b2f532405a2c505d380d52c4b8809876.jpg: 640x640 3 Canine (43)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 4 First Premolar (34)s, 1 First Premolar (44), 2 Lateral Incisor (32)s, 3 Lateral Incisor (42)s, 1 Second Molar (37), 1 Second Molar (47), 556.5ms
# image 31/51 /content/dataset_prepared/images/test/cate5-00102_jpg.rf.bacc49b0f354808df1e427b4e692ad88.jpg: 640x640 1 Canine (33), 2 Canine (43)s, 1 Central Incisor (41), 1 Central Incisor (31), 2 First Premolar (34)s, 2 Lateral Incisor (32)s, 4 Lateral Incisor (42)s, 1 Second Molar (37), 2 Second Molar (47)s, 838.4ms
# image 32/51 /content/dataset_prepared/images/test/cate5-00103_jpg.rf.f8f4b0b4f50f530621b5495ba388ec47.jpg: 640x640 5 Canine (13)s, 2 Canine (43)s, 3 Central Incisor (21)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Premolar (34), 1 First Premolar (44), 2 Lateral Incisor (32)s, 2 Lateral Incisor (42)s, 1 Lateral Incisor (12), 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Premolar (25), 1 Second Premolar (45), 1 Third Molar (18), 847.3ms
# image 33/51 /content/dataset_prepared/images/test/cate5-00109_jpg.rf.b228b13645b1197647b308d0c2250412.jpg: 640x640 1 Canine (13), 1 Canine (43), 4 Central Incisor (41)s, 3 Central Incisor (31)s, 1 First Premolar (14), 1 First Premolar (44), 1 Lateral Incisor (32), 3 Lateral Incisor (42)s, 1 Second Premolar (35), 793.7ms
# image 34/51 /content/dataset_prepared/images/test/cate6-00063_jpg.rf.ac7f40e1228de6c900c569a5d9f8b044.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Canine (43)s, 2 Central Incisor (21)s, 3 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (26), 2 First Molar (46)s, 3 First Premolar (44)s, 3 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (37), 3 Second Molar (47)s, 1 Second Premolar (35), 2 Second Premolar (45)s, 4 Third Molar (18)s, 3 Third Molar (28)s, 2 Third Molar (38)s, 4 Third Molar (48)s, 547.8ms
# image 35/51 /content/dataset_prepared/images/test/cate6-00075_jpg.rf.ca4afe79ad1594b3fb8c3c41a72cfb10.jpg: 640x640 1 Canine (33), 1 Canine (43), 3 Central Incisor (21)s, 3 Central Incisor (41)s, 1 Central Incisor (31), 2 Central Incisor (11)s, 1 Second Molar (17), 1 Second Molar (27), 2 Second Molar (47)s, 2 Third Molar (18)s, 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 559.1ms
# image 36/51 /content/dataset_prepared/images/test/cate6-00087_jpg.rf.0b8f6ac1157c7f4a78fe351de087c3a1.jpg: 640x640 2 Canine (43)s, 1 Central Incisor (21), 1 Central Incisor (41), 1 Central Incisor (31), 2 Central Incisor (11)s, 1 First Molar (16), 1 First Molar (46), 1 Lateral Incisor (42), 2 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (47)s, 1 Third Molar (18), 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 564.0ms
# image 37/51 /content/dataset_prepared/images/test/cate6-00093_jpg.rf.7ee6d6ffc4ba11e6e96146f65800cb82.jpg: 640x640 1 Central Incisor (21), 1 Central Incisor (11), 1 Lateral Incisor (22), 1 Lateral Incisor (42), 2 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 3 Second Molar (47)s, 1 Third Molar (18), 3 Third Molar (28)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 551.4ms
# image 38/51 /content/dataset_prepared/images/test/cate6-00099_jpg.rf.66421231c2c5a935538c461b06d72087.jpg: 640x640 2 Canine (33)s, 2 Central Incisor (21)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 1 First Molar (46), 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (27)s, 2 Second Molar (37)s, 4 Second Molar (47)s, 2 Second Premolar (45)s, 2 Third Molar (18)s, 3 Third Molar (38)s, 3 Third Molar (48)s, 563.7ms
# image 39/51 /content/dataset_prepared/images/test/cate7-00011_jpg.rf.c69e41a99068ff6c739d526685d3c151.jpg: 640x640 1 Canine (23), 1 Canine (33), 1 Canine (43), 1 Central Incisor (21), 2 Central Incisor (41)s, 5 Central Incisor (31)s, 1 First Molar (16), 1 First Molar (26), 2 First Premolar (34)s, 3 First Premolar (44)s, 1 Lateral Incisor (22), 1 Second Molar (17), 2 Second Molar (27)s, 1 Second Molar (37), 2 Second Premolar (35)s, 1 Third Molar (48), 551.2ms
# image 40/51 /content/dataset_prepared/images/test/cate7-00074_jpg.rf.12a01f3dc902c5e705afe61f89aa0f44.jpg: 640x640 2 Canine (33)s, 2 Central Incisor (21)s, 3 Central Incisor (41)s, 1 Central Incisor (31), 2 Central Incisor (11)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (46), 3 First Premolar (34)s, 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 2 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 3 Second Molar (47)s, 2 Second Premolar (25)s, 1 Second Premolar (35), 2 Second Premolar (45)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 566.8ms
# image 41/51 /content/dataset_prepared/images/test/cate7-00104_jpg.rf.755fda6da3d9dbafaff1c7be18013a48.jpg: 640x640 1 Canine (33), 3 Canine (43)s, 3 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 3 Central Incisor (11)s, 1 First Molar (16), 2 First Molar (26)s, 1 First Molar (46), 1 First Premolar (34), 3 First Premolar (44)s, 1 First Premolar (24), 4 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (37), 4 Second Molar (47)s, 1 Third Molar (18), 2 Third Molar (28)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 549.5ms
# image 42/51 /content/dataset_prepared/images/test/cate8-00023_jpg.rf.b2e358f22850af1b16d860cc49bd25fc.jpg: 640x640 1 Canine (33), 1 Central Incisor (21), 4 Central Incisor (41)s, 2 Central Incisor (31)s, 1 First Molar (16), 2 First Molar (26)s, 2 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 3 Lateral Incisor (42)s, 2 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (37), 2 Second Molar (47)s, 2 Second Premolar (25)s, 1 Second Premolar (35), 2 Second Premolar (45)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 2 Third Molar (48)s, 568.5ms
# image 43/51 /content/dataset_prepared/images/test/cate8-00053_jpg.rf.c59157b3aad8afbcb5b589f7094cabdc.jpg: 640x640 1 Canine (13), 1 Canine (23), 1 Canine (43), 4 Central Incisor (41)s, 3 Central Incisor (31)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (36), 1 First Molar (46), 3 First Premolar (44)s, 1 Lateral Incisor (32), 3 Lateral Incisor (42)s, 3 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 1 Second Molar (47), 2 Second Premolar (45)s, 1 Third Molar (38), 1 Third Molar (48), 551.9ms
# image 44/51 /content/dataset_prepared/images/test/cate8-00065_jpg.rf.e9397184c7101fc96d6882eca2a360e4.jpg: 640x640 2 Canine (23)s, 1 Central Incisor (21), 3 Central Incisor (41)s, 4 Central Incisor (31)s, 2 Central Incisor (11)s, 3 First Molar (16)s, 2 First Molar (26)s, 2 First Molar (46)s, 1 First Premolar (44), 1 Lateral Incisor (22), 1 Lateral Incisor (42), 2 Second Molar (17)s, 2 Second Molar (27)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 567.5ms
# image 45/51 /content/dataset_prepared/images/test/cate8-00221_jpg.rf.3fdb9cff3e6302c3e6e747d394c1c2ea.jpg: 640x640 1 Canine (23), 1 Canine (33), 2 Canine (43)s, 1 Central Incisor (21), 2 Central Incisor (41)s, 2 Central Incisor (31)s, 2 Central Incisor (11)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Premolar (34), 2 Lateral Incisor (22)s, 1 Lateral Incisor (32), 1 Lateral Incisor (42), 2 Second Molar (17)s, 2 Second Molar (27)s, 552.8ms
# image 46/51 /content/dataset_prepared/images/test/cate8-00325_jpg.rf.6cbdfaffbfa225a907e3780fe83894ef.jpg: 640x640 1 Canine (33), 1 Canine (43), 1 Central Incisor (21), 2 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 5 First Molar (16)s, 3 First Molar (26)s, 1 First Molar (36), 1 First Molar (46), 1 Lateral Incisor (22), 2 Lateral Incisor (32)s, 2 Lateral Incisor (42)s, 4 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 2 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (28), 2 Third Molar (48)s, 547.1ms
# image 47/51 /content/dataset_prepared/images/test/cate8-00447_jpg.rf.555e087c41682275bb44555b40adca25.jpg: 640x640 1 Canine (13), 2 Canine (33)s, 1 Canine (43), 3 Central Incisor (41)s, 1 Central Incisor (31), 2 Central Incisor (11)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Premolar (14), 3 First Premolar (34)s, 2 Lateral Incisor (22)s, 2 Lateral Incisor (42)s, 1 Second Molar (17), 1 Second Molar (27), 1 Second Molar (37), 1 Second Molar (47), 2 Second Premolar (25)s, 1 Third Molar (18), 1 Third Molar (28), 2 Third Molar (48)s, 555.9ms
# image 48/51 /content/dataset_prepared/images/test/d1f49454-20240729-105642516.jpg: 640x640 1 Canine (13), 2 Central Incisor (21)s, 3 Central Incisor (41)s, 1 Central Incisor (31), 1 First Molar (16), 2 First Molar (26)s, 2 First Molar (36)s, 3 First Molar (46)s, 2 First Premolar (24)s, 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 2 Second Molar (17)s, 3 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 2 Third Molar (48)s, 548.7ms
# image 49/51 /content/dataset_prepared/images/test/f0c433c8-20240704-131443960.jpg: 640x640 1 First Molar (26), 2 First Molar (36)s, 2 First Molar (46)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 3 Second Molar (27)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 3 Second Premolar (45)s, 1 Third Molar (28), 1 Third Molar (38), 1 Third Molar (48), 558.0ms
# image 50/51 /content/dataset_prepared/images/test/f1e56772-20250428-124704468.jpg: 640x640 1 Central Incisor (21), 5 Central Incisor (41)s, 1 Central Incisor (11), 1 First Molar (16), 3 First Molar (36)s, 2 First Molar (46)s, 1 Lateral Incisor (22), 1 Lateral Incisor (42), 2 Second Molar (27)s, 3 Second Molar (37)s, 1 Second Premolar (35), 1 Third Molar (28), 1 Third Molar (38), 2 Third Molar (48)s, 547.9ms
# image 51/51 /content/dataset_prepared/images/test/f88f1a7f-20240819-122056082.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (11)s, 1 First Molar (26), 2 First Molar (36)s, 1 First Molar (46), 1 First Premolar (44), 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (47), 4 Second Premolar (35)s, 2 Second Premolar (45)s, 1 Third Molar (28), 2 Third Molar (48)s, 778.9ms
# Speed: 2.8ms preprocess, 590.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/predict_vis2
# Predictions saved under: /content/runs/predict_vis

# %%
# Inline display of a few predictions using Results.plot()
to_show = pred_results[:NUM_INLINE_PREVIEWS] if isinstance(pred_results, list) else []
fig_cols = 3
fig_rows = max(1, int(np.ceil(len(to_show) / fig_cols)))
if len(to_show) > 0:
    plt.figure(figsize=(fig_cols * 5, fig_rows * 4))
    for i, res in enumerate(to_show):
        im_bgr = res.plot()  # BGR numpy array
        im_rgb = im_bgr[..., ::-1]
        plt.subplot(fig_rows, fig_cols, i + 1)
        plt.imshow(im_rgb)
        plt.axis("off")
        plt.title(Path(res.path).name if hasattr(res, "path") else f"pred_{i}")
    plt.tight_layout()
    plt.show()

# %%
# Also save a grid preview image
preview_path = PRED_VIS_DIR / "preview_grid.png"
if len(to_show) > 0:
    plt.figure(figsize=(fig_cols * 5, fig_rows * 4))
    for i, res in enumerate(to_show):
        im_bgr = res.plot()
        im_rgb = im_bgr[..., ::-1]
        plt.subplot(fig_rows, fig_cols, i + 1)
        plt.imshow(im_rgb)
        plt.axis("off")
        plt.title(Path(res.path).name if hasattr(res, "path") else f"pred_{i}")
    plt.tight_layout()
    plt.savefig(preview_path, dpi=150)
    plt.close()
    print("Saved inline preview grid to:", preview_path)
# Out:
# Saved inline preview grid to: /content/runs/predict_vis/preview_grid.png

# %%
# Optional Post-Processing for anatomical consistency

CLASS_ID_TO_FDI = {i: name.split("(")[-1].strip(")") for i, name in enumerate(FDI_CLASS_NAMES)}

def load_yolo_labels(label_path: Path) -> np.ndarray:
    if not label_path.exists():
        return np.zeros((0, 5), dtype=float)
    rows = []
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) >= 5:
                rows.append([float(p) for p in parts[:5]])
    if not rows:
        return np.zeros((0, 5), dtype=float)
    return np.array(rows, dtype=float)  # cls, cx, cy, w, h

def save_yolo_labels(label_path: Path, arr: np.ndarray):
    with open(label_path, "w") as f:
        for row in arr:
            f.write(f"{int(row[0])} {row[1]:.6f} {row[2]:.6f} {row[3]:.6f} {row[4]:.6f}\n")

def kmeans_split_y(values: np.ndarray) -> np.ndarray:
    try:
        from sklearn.cluster import KMeans
        km = KMeans(n_clusters=2, random_state=SEED, n_init=10)
        labels = km.fit_predict(values.reshape(-1, 1))
        return labels
    except Exception:
        med = np.median(values)
        return (values > med).astype(int)

def assign_quadrants_and_sort(boxes: np.ndarray) -> Dict[str, List[int]]:
    N = boxes.shape[0]
    if N == 0:
        return {}

    cy = boxes[:, 2]
    arch_labels = kmeans_split_y(cy)
    upper_cluster = int(np.argmin([cy[arch_labels == k].mean() if np.any(arch_labels == k) else 1e9 for k in [0, 1]]))

    quadrants = {"1": [], "2": [], "3": [], "4": []}
    for idx in range(N):
        cx = boxes[idx, 1]
        is_upper = (arch_labels[idx] == upper_cluster)
        if is_upper:
            if cx < 0.5:
                quadrants["2"].append(idx)
            else:
                quadrants["1"].append(idx)
        else:
            if cx < 0.5:
                quadrants["3"].append(idx)
            else:
                quadrants["4"].append(idx)

    for q in ["1", "2", "3", "4"]:
        quadrants[q].sort(key=lambda i: boxes[i, 1])
    return quadrants

def expected_fdi_sequence_for_quadrant(q: str) -> List[str]:
    base = {"1": 10, "2": 20, "3": 30, "4": 40}[q]
    return [f"{base + i}" for i in range(1, 9)]

def map_fdi_to_class_index(fdi_code: str) -> Optional[int]:
    for i, name in enumerate(FDI_CLASS_NAMES):
        fdi = name.split("(")[-1].strip(")")
        if fdi == fdi_code:
            return i
    return None

def postprocess_image(img_path: Path, in_label_path: Path, out_label_path: Path, out_vis_path: Path):
    boxes = load_yolo_labels(in_label_path)  # (N,5)
    if boxes.shape[0] == 0:
        return

    quads = assign_quadrants_and_sort(boxes)
    new_boxes = boxes.copy()

    for q, idxs in quads.items():
        seq = expected_fdi_sequence_for_quadrant(q)
        for k, idx in enumerate(idxs):
            if k >= len(seq):
                break
            target_fdi = seq[k]
            target_cls = map_fdi_to_class_index(fdi_code=target_fdi)
            if target_cls is not None:
                new_boxes[idx, 0] = target_cls

    save_yolo_labels(out_label_path, new_boxes)

    img = cv2.imread(str(img_path))
    if img is None:
        return
    h, w = img.shape[:2]
    vis = img.copy()
    for row in new_boxes:
        cls, cx, cy, bw, bh = row
        cls = int(cls)
        x = int((cx - bw / 2) * w)
        y = int((cy - bh / 2) * h)
        x2 = int((cx + bw / 2) * w)
        y2 = int((cy + bh / 2) * h)
        label = FDI_CLASS_NAMES[cls].split("(")[-1].strip(")")
        cv2.rectangle(vis, (x, y), (x2, y2), (0, 255, 0), 2)
        cv2.putText(vis, label, (x, max(15, y - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (10, 200, 10), 2, cv2.LINE_AA)

    out_vis_path.parent.mkdir(parents=True, exist_ok=True)
    cv2.imwrite(str(out_vis_path), vis)

# %%
# Ensure dirs
ensure_clean_dir(POSTPROC_VIS_DIR)

# Re-run predictions with label TXT saving for post-processing
preds_with_txt = YOLO(str(best_pt)).predict(
    source=str(OUT_ROOT/"images"/"test"),
    save=True,
    save_txt=True,
    conf=CONF_THRESH,
    iou=IOU_THRESH,
    imgsz=RECOMMENDED_IMG_SIZE,
    project=str(PRED_VIS_DIR.parent),
    name=PRED_VIS_DIR.name
)
labels_pred_dir = PRED_VIS_DIR / "labels"

# Post-process predictions
POSTPROC_LABELS_DIR = RUNS_ROOT / "postproc_labels"
ensure_clean_dir(POSTPROC_LABELS_DIR)

test_images_dir = OUT_ROOT / "images" / "test"
for img_path in tqdm(sorted(test_images_dir.glob("*")), desc="Post-processing", unit="img"):
    if img_path.suffix.lower() not in IMG_EXTS:
        continue
    label_path = labels_pred_dir / f"{img_path.stem}.txt"
    out_label_path = POSTPROC_LABELS_DIR / f"{img_path.stem}.txt"
    out_vis_path = POSTPROC_VIS_DIR / img_path.name
    if label_path.exists():
        postprocess_image(img_path, label_path, out_label_path, out_vis_path)

print("Post-processed visuals saved to:", POSTPROC_VIS_DIR)
print("Post-processed labels saved to:", POSTPROC_LABELS_DIR)

# Inline display of a few post-processed images for verification
postproc_images = sorted([p for p in POSTPROC_VIS_DIR.glob("*") if p.suffix.lower() in IMG_EXTS])[:NUM_INLINE_PREVIEWS]
if len(postproc_images) > 0:
    fig_cols = 3
    fig_rows = max(1, int(np.ceil(len(postproc_images) / fig_cols)))
    plt.figure(figsize=(fig_cols * 5, fig_rows * 4))
    for i, p in enumerate(postproc_images):
        bgr = cv2.imread(str(p))
        rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
        plt.subplot(fig_rows, fig_cols, i + 1)
        plt.imshow(rgb)
        plt.axis("off")
        plt.title(p.name)
    plt.tight_layout()
    plt.show()
# Out:
# image 1/51 /content/dataset_prepared/images/test/069750f6-20240914-102814322.jpg: 640x640 1 Central Incisor (21), 2 Central Incisor (41)s, 2 First Molar (36)s, 2 Lateral Incisor (22)s, 3 Lateral Incisor (32)s, 3 Lateral Incisor (42)s, 1 Second Molar (17), 1 Second Molar (27), 1 Third Molar (28), 1 Third Molar (48), 562.8ms
# image 2/51 /content/dataset_prepared/images/test/084c3562-20240827-154718191.jpg: 640x640 3 Canine (13)s, 1 Canine (33), 3 Central Incisor (21)s, 4 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (36), 1 First Molar (46), 2 Lateral Incisor (22)s, 1 Second Molar (17), 1 Second Molar (27), 2 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (35), 2 Third Molar (48)s, 560.1ms
# image 3/51 /content/dataset_prepared/images/test/22464331-20240919-102844605.jpg: 640x640 1 Canine (33), 3 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 2 First Molar (26)s, 2 First Molar (36)s, 3 First Molar (46)s, 2 First Premolar (44)s, 1 First Premolar (24), 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (15), 3 Second Premolar (35)s, 1 Third Molar (18), 2 Third Molar (38)s, 2 Third Molar (48)s, 538.4ms
# image 4/51 /content/dataset_prepared/images/test/2725830c-20240829-130426513.jpg: 640x640 2 Central Incisor (21)s, 2 Central Incisor (41)s, 3 First Molar (26)s, 1 First Molar (36), 3 First Molar (46)s, 1 First Premolar (14), 1 First Premolar (44), 3 Lateral Incisor (22)s, 1 Lateral Incisor (32), 1 Lateral Incisor (42), 2 Second Molar (17)s, 4 Second Molar (37)s, 3 Second Molar (47)s, 2 Second Premolar (35)s, 1 Third Molar (28), 2 Third Molar (48)s, 560.2ms
# image 5/51 /content/dataset_prepared/images/test/2b1da7b0-20240813-114403429.jpg: 640x640 1 Canine (33), 2 Central Incisor (21)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (44), 1 First Premolar (24), 2 Lateral Incisor (22)s, 2 Lateral Incisor (32)s, 3 Lateral Incisor (42)s, 3 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 2 Second Molar (47)s, 2 Second Premolar (15)s, 1 Second Premolar (25), 2 Second Premolar (35)s, 1 Second Premolar (45), 2 Third Molar (38)s, 2 Third Molar (48)s, 542.8ms
# image 6/51 /content/dataset_prepared/images/test/2d87cff9-20240801-161145471.jpg: 640x640 1 Central Incisor (21), 2 Central Incisor (11)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (36), 2 Lateral Incisor (22)s, 3 Second Molar (17)s, 1 Second Molar (37), 3 Second Molar (47)s, 1 Third Molar (38), 2 Third Molar (48)s, 550.2ms
# image 7/51 /content/dataset_prepared/images/test/3ffe5987-20240830-141140390.jpg: 640x640 2 Central Incisor (21)s, 3 Central Incisor (41)s, 3 Central Incisor (31)s, 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 2 Second Molar (17)s, 2 Second Molar (27)s, 1 Third Molar (38), 2 Third Molar (48)s, 544.2ms
# image 8/51 /content/dataset_prepared/images/test/46f25eb3-20240716-144513555.jpg: 640x640 2 Canine (33)s, 1 Canine (43), 1 Central Incisor (41), 3 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (36), 1 First Molar (46), 2 Lateral Incisor (42)s, 5 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 2 Second Molar (47)s, 2 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 552.3ms
# image 9/51 /content/dataset_prepared/images/test/4a54fcae-20240808-115419598.jpg: 640x640 2 Central Incisor (21)s, 3 Central Incisor (41)s, 1 First Molar (26), 2 First Molar (36)s, 1 Lateral Incisor (22), 1 Second Molar (17), 1 Second Molar (27), 2 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (35), 2 Third Molar (28)s, 2 Third Molar (48)s, 545.4ms
# image 10/51 /content/dataset_prepared/images/test/57f405c1-20240726-112759687.jpg: 640x640 1 Canine (13), 2 Central Incisor (21)s, 1 Central Incisor (41), 2 Central Incisor (31)s, 1 First Molar (16), 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 3 First Premolar (44)s, 2 Lateral Incisor (22)s, 1 Lateral Incisor (32), 4 Second Molar (17)s, 2 Second Molar (27)s, 4 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (25), 3 Second Premolar (35)s, 1 Third Molar (28), 1 Third Molar (38), 2 Third Molar (48)s, 559.1ms
# image 11/51 /content/dataset_prepared/images/test/61e47c05-20240709-160829783.jpg: 640x640 1 Canine (33), 2 Central Incisor (21)s, 2 Central Incisor (41)s, 1 Central Incisor (31), 2 First Molar (16)s, 1 First Molar (36), 1 First Premolar (24), 5 Lateral Incisor (22)s, 1 Second Molar (17), 1 Second Molar (27), 3 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (35), 1 Third Molar (48), 558.1ms
# image 12/51 /content/dataset_prepared/images/test/a5c76dbc-20240729-122640382.jpg: 640x640 2 Canine (13)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (34), 3 Lateral Incisor (22)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 2 Second Premolar (35)s, 2 Second Premolar (45)s, 1 Third Molar (28), 544.3ms
# image 13/51 /content/dataset_prepared/images/test/b94abb31-20250429-142751426.jpg: 640x640 1 Canine (33), 2 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 3 First Molar (16)s, 3 First Molar (26)s, 2 First Molar (36)s, 2 First Molar (46)s, 2 First Premolar (34)s, 2 First Premolar (44)s, 1 First Premolar (24), 3 Lateral Incisor (22)s, 2 Second Molar (17)s, 1 Second Molar (27), 3 Second Molar (37)s, 1 Second Molar (47), 1 Second Premolar (15), 3 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 557.6ms
# image 14/51 /content/dataset_prepared/images/test/bd3e04e6-20240808-115757352.jpg: 640x640 3 Canine (13)s, 1 Canine (33), 2 Central Incisor (21)s, 5 Central Incisor (41)s, 1 Central Incisor (31), 1 Central Incisor (11), 1 First Molar (16), 1 First Molar (26), 2 First Molar (36)s, 2 First Molar (46)s, 1 First Premolar (34), 1 First Premolar (44), 2 First Premolar (24)s, 2 Lateral Incisor (22)s, 2 Second Molar (17)s, 1 Second Molar (37), 1 Second Molar (47), 1 Second Premolar (15), 1 Second Premolar (25), 2 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (48)s, 547.2ms
# image 15/51 /content/dataset_prepared/images/test/cate1-00035_jpg.rf.e82433024ad10ea2a258614c2a8d3c5f.jpg: 640x640 2 Canine (13)s, 1 Canine (33), 3 Canine (43)s, 2 Central Incisor (21)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 3 First Molar (16)s, 3 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (34), 4 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 3 Second Molar (17)s, 1 Second Molar (37), 3 Second Molar (47)s, 1 Second Premolar (25), 1 Second Premolar (45), 3 Third Molar (18)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 549.5ms
# image 16/51 /content/dataset_prepared/images/test/cate1-00038_jpg.rf.3c63a693eae24c5155b6f1282928630d.jpg: 640x640 1 Canine (43), 3 Central Incisor (21)s, 4 Central Incisor (41)s, 4 Central Incisor (31)s, 2 Central Incisor (11)s, 4 First Molar (16)s, 3 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (24), 1 Lateral Incisor (22), 4 Lateral Incisor (42)s, 4 Second Molar (17)s, 4 Second Molar (37)s, 3 Second Molar (47)s, 1 Second Premolar (25), 2 Third Molar (48)s, 570.0ms
# image 17/51 /content/dataset_prepared/images/test/cate10-00056_jpg.rf.e283da4454bc0607fd574ffbdbb20db6.jpg: 640x640 2 Canine (33)s, 1 Central Incisor (41), 1 Central Incisor (31), 3 Lateral Incisor (42)s, 852.7ms
# image 18/51 /content/dataset_prepared/images/test/cate10-00096_jpg.rf.847ccd33e35016442a58b3832dfcc488.jpg: 640x640 3 Canine (33)s, 4 Canine (43)s, 3 Central Incisor (21)s, 2 Central Incisor (41)s, 3 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 2 First Molar (46)s, 2 First Premolar (44)s, 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 1 Second Molar (17), 2 Second Molar (27)s, 1 Second Molar (37), 2 Second Molar (47)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 1 Third Molar (48), 863.1ms
# image 19/51 /content/dataset_prepared/images/test/cate10-00099_jpg.rf.930b392526a8d7c5bd58de4ef8d8913b.jpg: 640x640 1 Canine (43), 724.7ms
# image 20/51 /content/dataset_prepared/images/test/cate2-00002_jpg.rf.88df00cce5a1d60ebf0e6b7fd48b8e71.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Canine (43)s, 3 Central Incisor (21)s, 1 Central Incisor (41), 3 Central Incisor (31)s, 2 Central Incisor (11)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (46), 1 First Premolar (34), 3 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 1 Lateral Incisor (42), 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (47), 1 Second Premolar (45), 1 Third Molar (28), 2 Third Molar (38)s, 3 Third Molar (48)s, 546.4ms
# image 21/51 /content/dataset_prepared/images/test/cate2-00010_jpg.rf.8deab81916101ce7c23a61d31df4459b.jpg: 640x640 1 Canine (43), 4 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 3 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (46), 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 4 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (38), 2 Third Molar (48)s, 558.3ms
# image 22/51 /content/dataset_prepared/images/test/cate2-00014_jpg.rf.d7f786ae7e337fd90b4661215a8692fb.jpg: 640x640 1 Canine (33), 3 Canine (43)s, 1 Central Incisor (21), 1 Central Incisor (41), 2 First Molar (16)s, 3 First Molar (26)s, 2 First Molar (46)s, 1 First Premolar (34), 2 First Premolar (44)s, 4 Second Molar (17)s, 1 Second Molar (27), 3 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (38), 1 Third Molar (48), 544.1ms
# image 23/51 /content/dataset_prepared/images/test/cate2-00020_jpg.rf.16b91f29e3feccbedf95e0ab37e4dd37.jpg: 640x640 1 Canine (13), 1 Canine (33), 3 Canine (43)s, 3 Central Incisor (21)s, 2 Central Incisor (31)s, 1 First Molar (16), 2 First Molar (26)s, 1 First Molar (46), 1 First Premolar (34), 1 First Premolar (44), 2 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (37)s, 3 Second Molar (47)s, 2 Second Premolar (25)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 1 Third Molar (38), 2 Third Molar (48)s, 564.7ms
# image 24/51 /content/dataset_prepared/images/test/cate2-00024_jpg.rf.fcdad1d1e96e782bead30ea33af7ed9f.jpg: 640x640 2 Canine (13)s, 1 Canine (23), 2 Canine (43)s, 2 Central Incisor (21)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (44), 1 First Premolar (24), 2 Lateral Incisor (42)s, 2 Second Molar (17)s, 2 Second Molar (27)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 2 Third Molar (18)s, 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 539.5ms
# image 25/51 /content/dataset_prepared/images/test/cate2-00109_jpg.rf.4f7ba9a179030058bf19f2f8cb3958b1.jpg: 640x640 1 Canine (33), 2 Canine (43)s, 3 Central Incisor (41)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 2 First Premolar (44)s, 3 Lateral Incisor (22)s, 1 Lateral Incisor (32), 1 Lateral Incisor (42), 2 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 3 Second Molar (47)s, 2 Second Premolar (25)s, 1 Second Premolar (35), 3 Second Premolar (45)s, 2 Third Molar (18)s, 1 Third Molar (28), 1 Third Molar (38), 2 Third Molar (48)s, 554.7ms
# image 26/51 /content/dataset_prepared/images/test/cate4-00094_jpg.rf.75f97439f6514548ed5deec49508d88c.jpg: 640x640 2 Canine (43)s, 2 Central Incisor (21)s, 4 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 2 First Molar (46)s, 1 First Premolar (34), 2 First Premolar (44)s, 1 Lateral Incisor (32), 2 Lateral Incisor (42)s, 4 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 2 Second Molar (47)s, 2 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (18)s, 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 557.5ms
# image 27/51 /content/dataset_prepared/images/test/cate4-00131_jpg.rf.dceada043e33cbad1bc1b57ed1243bfc.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Canine (43)s, 1 Central Incisor (21), 2 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (26), 2 First Molar (36)s, 2 First Molar (46)s, 2 First Premolar (34)s, 2 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 1 Lateral Incisor (42), 3 Second Molar (17)s, 1 Second Molar (37), 2 Second Molar (47)s, 1 Second Premolar (25), 3 Second Premolar (35)s, 2 Second Premolar (45)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 551.0ms
# image 28/51 /content/dataset_prepared/images/test/cate5-00024_jpg.rf.56e9a8ce944902108d3fc06b7e082c18.jpg: 640x640 2 Canine (13)s, 1 Canine (43), 1 Central Incisor (21), 2 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 3 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 1 First Molar (46), 1 First Premolar (44), 1 Lateral Incisor (22), 3 Lateral Incisor (42)s, 2 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Premolar (45), 1 Third Molar (38), 1 Third Molar (48), 557.8ms
# image 29/51 /content/dataset_prepared/images/test/cate5-00078_jpg.rf.00ab602ee40aaa203757588ec19bd491.jpg: 640x640 1 Canine (33), 2 Central Incisor (41)s, 3 Central Incisor (31)s, 1 First Premolar (34), 1 First Premolar (44), 4 Lateral Incisor (32)s, 2 Lateral Incisor (42)s, 1 Second Molar (37), 2 Second Molar (47)s, 1 Third Molar (48), 540.5ms
# image 30/51 /content/dataset_prepared/images/test/cate5-00102_jpg.rf.b2f532405a2c505d380d52c4b8809876.jpg: 640x640 3 Canine (43)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 4 First Premolar (34)s, 1 First Premolar (44), 2 Lateral Incisor (32)s, 3 Lateral Incisor (42)s, 1 Second Molar (37), 1 Second Molar (47), 559.6ms
# image 31/51 /content/dataset_prepared/images/test/cate5-00102_jpg.rf.bacc49b0f354808df1e427b4e692ad88.jpg: 640x640 1 Canine (33), 2 Canine (43)s, 1 Central Incisor (41), 1 Central Incisor (31), 2 First Premolar (34)s, 2 Lateral Incisor (32)s, 4 Lateral Incisor (42)s, 1 Second Molar (37), 2 Second Molar (47)s, 539.8ms
# image 32/51 /content/dataset_prepared/images/test/cate5-00103_jpg.rf.f8f4b0b4f50f530621b5495ba388ec47.jpg: 640x640 5 Canine (13)s, 2 Canine (43)s, 3 Central Incisor (21)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Premolar (34), 1 First Premolar (44), 2 Lateral Incisor (32)s, 2 Lateral Incisor (42)s, 1 Lateral Incisor (12), 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Premolar (25), 1 Second Premolar (45), 1 Third Molar (18), 562.2ms
# image 33/51 /content/dataset_prepared/images/test/cate5-00109_jpg.rf.b228b13645b1197647b308d0c2250412.jpg: 640x640 1 Canine (13), 1 Canine (43), 4 Central Incisor (41)s, 3 Central Incisor (31)s, 1 First Premolar (14), 1 First Premolar (44), 1 Lateral Incisor (32), 3 Lateral Incisor (42)s, 1 Second Premolar (35), 541.0ms
# image 34/51 /content/dataset_prepared/images/test/cate6-00063_jpg.rf.ac7f40e1228de6c900c569a5d9f8b044.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Canine (43)s, 2 Central Incisor (21)s, 3 Central Incisor (41)s, 3 Central Incisor (31)s, 1 Central Incisor (11), 2 First Molar (16)s, 1 First Molar (26), 2 First Molar (46)s, 3 First Premolar (44)s, 3 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (37), 3 Second Molar (47)s, 1 Second Premolar (35), 2 Second Premolar (45)s, 4 Third Molar (18)s, 3 Third Molar (28)s, 2 Third Molar (38)s, 4 Third Molar (48)s, 560.1ms
# image 35/51 /content/dataset_prepared/images/test/cate6-00075_jpg.rf.ca4afe79ad1594b3fb8c3c41a72cfb10.jpg: 640x640 1 Canine (33), 1 Canine (43), 3 Central Incisor (21)s, 3 Central Incisor (41)s, 1 Central Incisor (31), 2 Central Incisor (11)s, 1 Second Molar (17), 1 Second Molar (27), 2 Second Molar (47)s, 2 Third Molar (18)s, 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 554.2ms
# image 36/51 /content/dataset_prepared/images/test/cate6-00087_jpg.rf.0b8f6ac1157c7f4a78fe351de087c3a1.jpg: 640x640 2 Canine (43)s, 1 Central Incisor (21), 1 Central Incisor (41), 1 Central Incisor (31), 2 Central Incisor (11)s, 1 First Molar (16), 1 First Molar (46), 1 Lateral Incisor (42), 2 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (47)s, 1 Third Molar (18), 1 Third Molar (28), 2 Third Molar (38)s, 2 Third Molar (48)s, 571.2ms
# image 37/51 /content/dataset_prepared/images/test/cate6-00093_jpg.rf.7ee6d6ffc4ba11e6e96146f65800cb82.jpg: 640x640 1 Central Incisor (21), 1 Central Incisor (11), 1 Lateral Incisor (22), 1 Lateral Incisor (42), 2 Second Molar (17)s, 1 Second Molar (27), 2 Second Molar (37)s, 3 Second Molar (47)s, 1 Third Molar (18), 3 Third Molar (28)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 856.5ms
# image 38/51 /content/dataset_prepared/images/test/cate6-00099_jpg.rf.66421231c2c5a935538c461b06d72087.jpg: 640x640 2 Canine (33)s, 2 Central Incisor (21)s, 2 Central Incisor (41)s, 2 Central Incisor (31)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (36), 1 First Molar (46), 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (27)s, 2 Second Molar (37)s, 4 Second Molar (47)s, 2 Second Premolar (45)s, 2 Third Molar (18)s, 3 Third Molar (38)s, 3 Third Molar (48)s, 857.2ms
# image 39/51 /content/dataset_prepared/images/test/cate7-00011_jpg.rf.c69e41a99068ff6c739d526685d3c151.jpg: 640x640 1 Canine (23), 1 Canine (33), 1 Canine (43), 1 Central Incisor (21), 2 Central Incisor (41)s, 5 Central Incisor (31)s, 1 First Molar (16), 1 First Molar (26), 2 First Premolar (34)s, 3 First Premolar (44)s, 1 Lateral Incisor (22), 1 Second Molar (17), 2 Second Molar (27)s, 1 Second Molar (37), 2 Second Premolar (35)s, 1 Third Molar (48), 747.4ms
# image 40/51 /content/dataset_prepared/images/test/cate7-00074_jpg.rf.12a01f3dc902c5e705afe61f89aa0f44.jpg: 640x640 2 Canine (33)s, 2 Central Incisor (21)s, 3 Central Incisor (41)s, 1 Central Incisor (31), 2 Central Incisor (11)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Molar (46), 3 First Premolar (34)s, 1 Lateral Incisor (22), 2 Lateral Incisor (42)s, 2 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 3 Second Molar (47)s, 2 Second Premolar (25)s, 1 Second Premolar (35), 2 Second Premolar (45)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 542.3ms
# image 41/51 /content/dataset_prepared/images/test/cate7-00104_jpg.rf.755fda6da3d9dbafaff1c7be18013a48.jpg: 640x640 1 Canine (33), 3 Canine (43)s, 3 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (31)s, 3 Central Incisor (11)s, 1 First Molar (16), 2 First Molar (26)s, 1 First Molar (46), 1 First Premolar (34), 3 First Premolar (44)s, 1 First Premolar (24), 4 Lateral Incisor (42)s, 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (37), 4 Second Molar (47)s, 1 Third Molar (18), 2 Third Molar (28)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 565.3ms
# image 42/51 /content/dataset_prepared/images/test/cate8-00023_jpg.rf.b2e358f22850af1b16d860cc49bd25fc.jpg: 640x640 1 Canine (33), 1 Central Incisor (21), 4 Central Incisor (41)s, 2 Central Incisor (31)s, 1 First Molar (16), 2 First Molar (26)s, 2 First Premolar (44)s, 1 Lateral Incisor (22), 1 Lateral Incisor (32), 3 Lateral Incisor (42)s, 2 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (37), 2 Second Molar (47)s, 2 Second Premolar (25)s, 1 Second Premolar (35), 2 Second Premolar (45)s, 2 Third Molar (18)s, 2 Third Molar (28)s, 2 Third Molar (48)s, 537.9ms
# image 43/51 /content/dataset_prepared/images/test/cate8-00053_jpg.rf.c59157b3aad8afbcb5b589f7094cabdc.jpg: 640x640 1 Canine (13), 1 Canine (23), 1 Canine (43), 4 Central Incisor (41)s, 3 Central Incisor (31)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Molar (36), 1 First Molar (46), 3 First Premolar (44)s, 1 Lateral Incisor (32), 3 Lateral Incisor (42)s, 3 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 1 Second Molar (47), 2 Second Premolar (45)s, 1 Third Molar (38), 1 Third Molar (48), 554.4ms
# image 44/51 /content/dataset_prepared/images/test/cate8-00065_jpg.rf.e9397184c7101fc96d6882eca2a360e4.jpg: 640x640 2 Canine (23)s, 1 Central Incisor (21), 3 Central Incisor (41)s, 4 Central Incisor (31)s, 2 Central Incisor (11)s, 3 First Molar (16)s, 2 First Molar (26)s, 2 First Molar (46)s, 1 First Premolar (44), 1 Lateral Incisor (22), 1 Lateral Incisor (42), 2 Second Molar (17)s, 2 Second Molar (27)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 2 Third Molar (38)s, 2 Third Molar (48)s, 539.1ms
# image 45/51 /content/dataset_prepared/images/test/cate8-00221_jpg.rf.3fdb9cff3e6302c3e6e747d394c1c2ea.jpg: 640x640 1 Canine (23), 1 Canine (33), 2 Canine (43)s, 1 Central Incisor (21), 2 Central Incisor (41)s, 2 Central Incisor (31)s, 2 Central Incisor (11)s, 2 First Molar (16)s, 1 First Molar (26), 1 First Premolar (34), 2 Lateral Incisor (22)s, 1 Lateral Incisor (32), 1 Lateral Incisor (42), 2 Second Molar (17)s, 2 Second Molar (27)s, 551.1ms
# image 46/51 /content/dataset_prepared/images/test/cate8-00325_jpg.rf.6cbdfaffbfa225a907e3780fe83894ef.jpg: 640x640 1 Canine (33), 1 Canine (43), 1 Central Incisor (21), 2 Central Incisor (41)s, 2 Central Incisor (31)s, 1 Central Incisor (11), 5 First Molar (16)s, 3 First Molar (26)s, 1 First Molar (36), 1 First Molar (46), 1 Lateral Incisor (22), 2 Lateral Incisor (32)s, 2 Lateral Incisor (42)s, 4 Second Molar (17)s, 1 Second Molar (27), 1 Second Molar (37), 2 Second Molar (47)s, 1 Second Premolar (35), 1 Second Premolar (45), 1 Third Molar (28), 2 Third Molar (48)s, 567.4ms
# image 47/51 /content/dataset_prepared/images/test/cate8-00447_jpg.rf.555e087c41682275bb44555b40adca25.jpg: 640x640 1 Canine (13), 2 Canine (33)s, 1 Canine (43), 3 Central Incisor (41)s, 1 Central Incisor (31), 2 Central Incisor (11)s, 2 First Molar (16)s, 2 First Molar (26)s, 1 First Premolar (14), 3 First Premolar (34)s, 2 Lateral Incisor (22)s, 2 Lateral Incisor (42)s, 1 Second Molar (17), 1 Second Molar (27), 1 Second Molar (37), 1 Second Molar (47), 2 Second Premolar (25)s, 1 Third Molar (18), 1 Third Molar (28), 2 Third Molar (48)s, 551.4ms
# image 48/51 /content/dataset_prepared/images/test/d1f49454-20240729-105642516.jpg: 640x640 1 Canine (13), 2 Central Incisor (21)s, 3 Central Incisor (41)s, 1 Central Incisor (31), 1 First Molar (16), 2 First Molar (26)s, 2 First Molar (36)s, 3 First Molar (46)s, 2 First Premolar (24)s, 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 2 Second Molar (17)s, 3 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 2 Third Molar (48)s, 560.9ms
# image 49/51 /content/dataset_prepared/images/test/f0c433c8-20240704-131443960.jpg: 640x640 1 First Molar (26), 2 First Molar (36)s, 2 First Molar (46)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 3 Second Molar (27)s, 2 Second Molar (37)s, 2 Second Molar (47)s, 1 Second Premolar (35), 3 Second Premolar (45)s, 1 Third Molar (28), 1 Third Molar (38), 1 Third Molar (48), 542.6ms
# image 50/51 /content/dataset_prepared/images/test/f1e56772-20250428-124704468.jpg: 640x640 1 Central Incisor (21), 5 Central Incisor (41)s, 1 Central Incisor (11), 1 First Molar (16), 3 First Molar (36)s, 2 First Molar (46)s, 1 Lateral Incisor (22), 1 Lateral Incisor (42), 2 Second Molar (27)s, 3 Second Molar (37)s, 1 Second Premolar (35), 1 Third Molar (28), 1 Third Molar (38), 2 Third Molar (48)s, 570.5ms
# image 51/51 /content/dataset_prepared/images/test/f88f1a7f-20240819-122056082.jpg: 640x640 1 Canine (13), 1 Canine (33), 2 Central Incisor (21)s, 3 Central Incisor (41)s, 2 Central Incisor (11)s, 1 First Molar (26), 2 First Molar (36)s, 1 First Molar (46), 1 First Premolar (44), 2 Lateral Incisor (22)s, 1 Lateral Incisor (42), 3 Second Molar (17)s, 2 Second Molar (27)s, 1 Second Molar (47), 4 Second Premolar (35)s, 2 Second Premolar (45)s, 1 Third Molar (28), 2 Third Molar (48)s, 549.3ms
# Speed: 2.8ms preprocess, 583.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/predict_vis3
# 51 labels saved to /content/runs/predict_vis3/labels
# Post-processing: 100%|██████████| 51/51 [00:00<00:00, 17078.60img/s]
# Post-processed visuals saved to: /content/runs/postproc_vis
# Post-processed labels saved to: /content/runs/postproc_labels

# %%
# Manifest and final notes

manifest = {
    "dataset": {
        "raw": str(EXTRACT_ROOT),
        "prepared": str(OUT_ROOT),
        "data_yaml": str(OUT_ROOT/"data.yaml"),
        "num_pairs": len(pairs),
        "seed": SEED
    },
    "training": {
        "run_dir": str(train_save_dir),
        "best_weights": str(best_pt),
        "epochs": EPOCHS,
        "batch": BATCH,
        "imgsz": RECOMMENDED_IMG_SIZE
    },
    "evaluation": {
        "val_dir": str(val_dir),
        "test_dir": str(test_dir),
        "submission_artifacts": str(SUBMISSION_DIR)
    },
    "predictions": {
        "raw_vis_dir": str(PRED_VIS_DIR),
        "postproc_vis_dir": str(POSTPROC_VIS_DIR),
        "postproc_labels_dir": str(POSTPROC_LABELS_DIR)
    },
    "classes": {i: n for i, n in enumerate(FDI_CLASS_NAMES)}
}
SUBMISSION_DIR.mkdir(parents=True, exist_ok=True)
with open(SUBMISSION_DIR/"manifest.json", "w", encoding="utf-8") as f:
    json.dump(manifest, f, indent=2)

print("Completed. Key outputs:")
print(" - Best weights:", best_pt)
print(" - Metrics CSV/JSON:", SUBMISSION_DIR/"metrics_val.csv", SUBMISSION_DIR/"metrics_val.json",
      SUBMISSION_DIR/"metrics_test.csv", SUBMISSION_DIR/"metrics_test.json")
print(" - Confusion matrices and plots:", SUBMISSION_DIR/"val_plots", SUBMISSION_DIR/"test_plots")
print(" - Raw predictions:", PRED_VIS_DIR)
print(" - Post-processed predictions:", POSTPROC_VIS_DIR)
print(" - Manifest:", SUBMISSION_DIR/"manifest.json")
# Out:
# Completed. Key outputs:
#  - Best weights: /content/runs/train/weights/best.pt
#  - Metrics CSV/JSON: /content/runs/submission_artifacts/metrics_val.csv /content/runs/submission_artifacts/metrics_val.json /content/runs/submission_artifacts/metrics_test.csv /content/runs/submission_artifacts/metrics_test.json
#  - Confusion matrices and plots: /content/runs/submission_artifacts/val_plots /content/runs/submission_artifacts/test_plots
#  - Raw predictions: /content/runs/predict_vis
#  - Post-processed predictions: /content/runs/postproc_vis
#  - Manifest: /content/runs/submission_artifacts/manifest.json
